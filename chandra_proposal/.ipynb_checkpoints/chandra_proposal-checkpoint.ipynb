# %%
# %matplotlib inline 

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from matplotlib import rcParams

#these colors come from colorbrewer2.org. Each is an RGB triplet
dark2_colors = [(0.10588235294117647, 0.6196078431372549, 0.4666666666666667),
                (0.8509803921568627, 0.37254901960784315, 0.00784313725490196),
                (0.4588235294117647, 0.4392156862745098, 0.7019607843137254),
                (0.9058823529411765, 0.1607843137254902, 0.5411764705882353),
                (0.4, 0.6509803921568628, 0.11764705882352941),
                (0.9019607843137255, 0.6705882352941176, 0.00784313725490196),
                (0.6509803921568628, 0.4627450980392157, 0.11372549019607843),
                (0.4, 0.4, 0.4)]

rcParams['figure.figsize'] = (10, 6)
rcParams['figure.dpi'] = 150
rcParams['axes.color_cycle'] = dark2_colors
rcParams['lines.linewidth'] = 2
rcParams['axes.grid'] = True
rcParams['axes.facecolor'] = '#eeeeee'
rcParams['font.size'] = 14
rcParams['patch.edgecolor'] = 'none'

def remove_border(axes=None, top=False, right=False, left=True, bottom=True):
    """
    Minimize chartjunk by stripping out unnecesasry plot borders and axis ticks
    
    The top/right/left/bottom keywords toggle whether the corresponding plot border is drawn
    """
    ax = axes or plt.gca()
    ax.spines['top'].set_visible(top)
    ax.spines['right'].set_visible(right)
    ax.spines['left'].set_visible(left)
    ax.spines['bottom'].set_visible(bottom)
    
    #turn off all ticks
    ax.yaxis.set_ticks_position('none')
    ax.xaxis.set_ticks_position('none')
    
    #now re-enable visibles
    if top:
        ax.xaxis.tick_top()
    if bottom:
        ax.xaxis.tick_bottom()
    if left:
        ax.yaxis.tick_left()
    if right:
        ax.yaxis.tick_right()
        
pd.set_option('display.width', 500)
pd.set_option('display.max_columns', 100)

# %%
def cat_name(x):
    if x=='NORMAL GALAXIES: DIFFUSE EMISSION' or x=='NORMAL GALAXIES: X-RAY POPULATIONS':
        return 'NORMAL GALAXIES'
    elif x=='NORMAL STARS AND WD':
        return 'STARS AND WD'
    else:
        return x

# %%
df=pd.read_csv('cycle_01.csv')
df2=pd.read_csv('all_large.csv')

# %%
df2=df2.drop(['Type','Unnamed: 0'],1)

# %%
df2.rename(columns={'Time (ks)':'Time'},inplace=True)
df2=df2[df2['Category']!='Category']
df2['Year']=map(lambda x: '20'+x[0:2], df2['Proposal Number'])
df2=df2.fillna('Nan')
df2.Category=map(lambda x: x.strip(),df2.Category)
df2.replace('Nan',0)
df2.Category=df2.Category.apply(cat_name)
df2['Time']=df2['Time'].apply(float)
df2['Year']=df2['Year'].apply(float)
df2['PI Name'] = map(lambda x: x.upper().split()[-1], df2['PI Name'])

# %%
for i in range(16):
    dfi=pd.read_csv('cycle_%02i.csv'%(i+2))
    dfi.rename(columns={'Time (ks)':'Time'},inplace=True)
    dfi['Year']=int('20'+'%02i'%(i+2))
    df=pd.concat([df,dfi])

# %%
df=df.drop(['Type','Unnamed: 0'],1)
df=df[df['Category']!='Category']
df=df.set_index(np.arange(3662))
df=df.fillna('Nan')
df.Category=map(lambda x: x.strip(),df.Category)
df.replace('Nan',0)
df.Category=df.Category.apply(cat_name)
df['Time']=df['Time'].apply(float)
df['PI Name'] = map(lambda x: x.upper().split()[-1], df['PI Name'])
df['Title'] = map(lambda x: x.upper(), df['Title'])

# %%
dff=pd.concat([df,df2])
dff=dff.set_index(np.arange(3849))
dff['Year']=dff['Year']-2.
dff.head()
# Out:
#        Category   PI Name Proposal Number   Time                                              Title    Year
# 0  SOLAR SYSTEM   DENNERL         1100297  24.30  VENUS AND MARS: THE CLOSEST PLANETARY ANALOGUE...  1999.0
# 1  SOLAR SYSTEM     LISSE         1100323  32.00  AXAF LOW ENERGY SPECTROSCOPY AND PHOTOMETRIC I...  1999.0
# 2  SOLAR SYSTEM   KASTNER         1100334  40.00  X-RAY IMAGING OF THE INTERACTING WINDS OF PLAN...  1999.0
# 3  SOLAR SYSTEM      SNOW         1100814  50.00  ASSESSEMENT OF INTERSTELLAR DEPLETIONS THROUGH...  1999.0
# 4  SOLAR SYSTEM  VESTRAND         1100890  65.25  SOLVING THE PUZZLE OF COMETARY X-RAY ORIGIN: O...  1999.0

# %%
dff[map(lambda x: find_word(x,'JUPITER'), dff.Title)]
# Out:
#          Category    PI Name Proposal Number  Time                                              Title    Year
# 7    SOLAR SYSTEM    GARMIRE         1100045  40.3  ACIS OBSERVATION OF JUPITER AND THE GALILEAN S...  1999.0
# 319  SOLAR SYSTEM  GLADSTONE         2100148  36.0  THE MORPHOLOGY OF JOVIAN X-RAYS AND SUPPORT OF...  2000.0
# 628  SOLAR SYSTEM      WAITE         3100308  72.0                      X-RAY OBSERVATIONS OF JUPITER  2001.0
# 942  SOLAR SYSTEM     ELSNER         4100190  72.0  MULTIWAVELENGTH OBSERVATIONS OF JUPITER'S AURO...  2002.0

# %%
find_word(dff.Title[0],'VENUS')
# Out:
# True

# %%
def find_word(x,word):
    if word in x:
        return True
    else:
        return False

# %%
df.hist('Year',bins=17)
plt.title('All proposed and accpeted projects')
remove_border()
dff.hist('Year',bins=17)
plt.title('All proposed projects + large project')
remove_border()

# %%
dff.Category.value_counts().plot(kind='bar')
remove_border()

# %%
dff.Category.value_counts()
# Out:
# SN, SNR AND ISOLATED NS                       732
# ACTIVE GALAXIES AND QUASARS                   715
# CLUSTERS OF GALAXIES                          560
# BH AND NS BINARIES                            549
# STARS AND WD                                  539
# NORMAL GALAXIES                               357
# WD BINARIES AND CV                            155
# EXTRAGALACTIC DIFFUSE EMISSION AND SURVEYS    120
# GALACTIC DIFFUSE EMISSION AND SURVEYS          66
# SOLAR SYSTEM                                   41
# Nan                                            15
# Name: Category, dtype: int64

# %%
dff['Time'].groupby(dff['Category']).apply(sum)#/df.Category.value_counts()
#df.groupby(by=['Category'])['Time']
# Out:
# Category
# ACTIVE GALAXIES AND QUASARS                    90634.676667
# BH AND NS BINARIES                             64878.620000
# CLUSTERS OF GALAXIES                          113286.280000
# EXTRAGALACTIC DIFFUSE EMISSION AND SURVEYS     52309.800000
# GALACTIC DIFFUSE EMISSION AND SURVEYS          11449.500000
# NORMAL GALAXIES                                50682.664000
# Nan                                              981.000000
# SN, SNR AND ISOLATED NS                       115215.020000
# SOLAR SYSTEM                                    2951.150000
# STARS AND WD                                   60453.440000
# WD BINARIES AND CV                             14827.740000
# dtype: float64

# %%
dff['Time'].groupby(dff['Year']).apply(sum)
#plt.plot(dff['Time'].groupby(dff['Year']).apply(sum))
#dff['Time'].groupby(dff['Year']).hist(bins=30,log=True);
# Out:
# Year
# 1999.0    46044.170000
# 2000.0    32252.010000
# 2001.0    40240.840000
# 2002.0    28166.540000
# 2003.0    33214.440000
# 2004.0    28542.370000
# 2005.0    31798.660000
# 2006.0    28034.000000
# 2007.0    30176.200000
# 2008.0    28684.666667
# 2009.0    31770.374000
# 2010.0    31466.300000
# 2011.0    44078.180000
# 2012.0    41469.800000
# 2013.0    34301.000000
# 2014.0    36793.400000
# 2015.0    30636.940000
# dtype: float64

# %%
np.log10(dff['Time']).hist(by=dff['Year'],sharex=True,sharey=True,figsize=(15,10),bins=30);

# %%
plt.scatter(dff['Year'],dff['Time'],alpha=0.4)
plt.yscale('log')

x=dff['Year']
y=dff['Time']
z=np.polyfit(x,y,1)
p = np.poly1d(z)
plt.plot(x,p(x))
remove_border(left=True, bottom=True)

# %%
p16=dff['Time'].groupby(dff['Year']).apply(np.percentile,16)
p50=dff['Time'].groupby(dff['Year']).apply(np.percentile,50)
p84=dff['Time'].groupby(dff['Year']).apply(np.percentile,84)
plt.plot(p16)
plt.plot(p50)
plt.plot(p84)
plt.yscale('log')
plt.scatter(dff['Year'],dff['Time'],alpha=0.4)
#plt.ylim(0,300)

# %%
np.sort(dff['PI Name'].unique())
# Out:
# array(['ACERO', 'AGUEROS', 'AJELLO', 'ALEXANDER', 'ALIU', 'ALLEN',
#        'ALMAINI', 'ALTAMIRANO', 'ANABUKI', 'ANDERSON', "ANDRE'", 'ANDREON',
#        'ANDREWS', 'ANGELINI', 'APPLETON', 'ARABADJIS', 'ARNAUD',
#        'ARZOUMANIAN', 'ASSEF', 'AUDARD', 'AYRES', 'BAGANOFF', 'BALLY',
#        'BALMAN', 'BARGER', 'BARTH', 'BASRI', 'BASU-ZYCH', 'BAUER', 'BAUM',
#        'BEARDMORE', 'BECHTOLD', 'BECKER', 'BEHAR', 'BEIERSDORFER',
#        'BELLONI', 'BENSON', 'BENZ', 'BERG', 'BERGER', 'BERNARDINI',
#        'BEUTHER', 'BIANCHI', 'BILDSTEN', 'BINDER', 'BIRETTA', 'BIRKINSHAW',
#        'BLANTON', 'BLEEM', 'BLITZ', 'BLUNDELL', 'BODAGHEE', 'BOEHRINGER',
#        'BOETTCHER', 'BOGDAN', 'BOGDANOV', 'BOIRIN', 'BOMANS', 'BONAFEDE',
#        'BONAMENTE', 'BONDI', 'BORKOWSKI', 'BOROSON', 'BOTHUN', 'BOTTACINI',
#        'BOUWMAN', 'BOWER', 'BRAITO', 'BRANDT', 'BRANDUARDI-RAYMONT',
#        'BREGMAN', 'BRENNEMAN', 'BREUGEL', 'BRICKHOUSE', 'BRINKMAN',
#        'BRODWIN', 'BRORBY', 'BROTHERTON', 'BROWN', 'BRUNETTI', 'BRUSA',
#        'BUOTE', 'BURNS', 'BURROWS', 'BURWITZ', 'BUTLER', 'BUTT', 'BUXTON',
#        'BUZASI', 'BYKOV', 'CACKETT', 'CAGNONI', 'CALIBRATION', 'CALVET',
#        'CAMILO', 'CAMPANA', 'CANIZARES', 'CANNING', 'CAPETTI', 'CAPPI',
#        'CARILLI', 'CASSANO', 'CASSINELLI', 'CASTRO', 'CAVAGNOLO', 'CECIL',
#        'CHAKRABARTY', 'CHANDRA', 'CHARLES', 'CHARTAS', 'CHARY',
#        'CHATTERJEE', 'CHEN', 'CHERNYAKOVA', 'CHEUNG', 'CHIANG', 'CHOMIUK',
#        'CHRISTIAN', 'CHU', 'CHURCH', 'CHURCHWELL', 'CIVANO', 'CLAESKENS',
#        'CLARKE', 'CLARKSON', 'CLAVEL', 'CLEMENTS', 'COE', 'COHEN', 'COHN',
#        'COLBERT', 'COLLMAR', 'COMERFORD', 'CONSTANTIN', 'COOL', 'COORAY',
#        'COPPI', 'CORBEL', 'CORCORAN', 'CORDES', 'CORNELISSE', 'COSTAMANTE',
#        'COSTANTINI', 'COTE', 'COVEY', 'CRENSHAW', 'CROSTON', 'CUI',
#        'CZESLA', 'DADDI', 'DADINA', 'DAI', 'DAMIANI', 'DARLING', 'DAS',
#        'DAVID', 'DAVIS', 'DAWSON', 'DEGENAAR', 'DELANEY', 'DENNERL',
#        'DEWANGAN', 'DIEBALL', 'DJORGOVSKI', 'DOBRZYCKI', 'DONAHUE',
#        'DONLEY', 'DRAKE', 'DUBUS', 'DUPKE', 'DUPREE', 'DUPUIS', 'DURANT',
#        'DWARKADAS', 'EBELING', 'EBISAWA', 'ECKERT', 'EDELSON', 'EDGE',
#        'EIKENBERRY', 'ELLINGSON', 'ELSNER', 'ELVIS', 'ERACLEOUS', 'ERLUND',
#        'EROS', 'ESQUEJ', 'ETTORI', 'EVANS', 'EZOE', 'FABBIANO', 'FABIAN',
#        'FAN', 'FANG', 'FARRAR', 'FARRELL', 'FASSNACHT', 'FAVATA',
#        'FEIGELSON', 'FENDER', 'FENG', 'FEROCI', 'FERRARI', 'FESEN',
#        'FIGER', 'FILIPPENKO', 'FINGER', 'FINLEY', 'FINOGUENOV', 'FIORE',
#        'FLACCOMIO', 'FLEMING', 'FORBRICH', 'FORMAN', 'FOSSATI', 'FOX',
#        'FRAIL', 'FRANCA', 'FRUCHTER', 'FRUSCIONE', 'FUKAZAWA',
#        'FUSCO-FEMIANO', 'GAENSLER', 'GAETZ', 'GAGNE', 'GALEAZZI',
#        'GALLAGHER', 'GALLANT', 'GALLERANI', 'GALLO', 'GALLOWAY', 'GANGULY',
#        'GARCIA', 'GARCIA-ALVAREZ', 'GARMIRE', 'GASPERIN', 'GASTALDELLO',
#        'GAVRIIL', 'GELBORD', 'GELLER', 'GEORGAKAKIS', 'GEORGANOPOULOS',
#        'GEORGANTOPOULOS', 'GEORGE', 'GERKE', 'GETMAN', 'GEZARI', 'GHOSH',
#        'GIACCONI', 'GIACINTUCCI', 'GILES', 'GILLI', 'GITTI', 'GIUSTINI',
#        'GIZIS', 'GLADDERS', 'GLADSTONE', 'GLIOZZI', 'GOMEZ', 'GONZALEZ',
#        'GOSNELL', 'GOTTHELF', 'GOUDFROOIJ', 'GOULDING', 'GRADY', 'GRAHAM',
#        'GRANDI', 'GREEN', 'GREENE', 'GREENHILL', 'GREGG', 'GREINER',
#        'GRENIER', 'GRIMES', 'GRINBERG', 'GRINDLAY', 'GRISE', 'GROSSO',
#        'GRUENDL', 'GRUPE', 'GUAINAZZI', 'GUARCELLO', 'GUEDEL', 'GUENTHER',
#        'GUERRERO', 'GUINAN', 'GULTEKIN', 'GURVITS', 'GUVER', 'HAGGARD',
#        'HAILEY', 'HALL', 'HALPERN', 'HAMAGUCHI', 'HAMANN', 'HANKE',
#        'HARDCASTLE', 'HARRIS', 'HARRISON', 'HARRUS', 'HARTMANN',
#        'HASINGER', 'HATTORI', 'HAYASHIDA', 'HECKMAN', 'HEIDA', 'HEINDL',
#        'HEINKE', 'HEINZ', 'HELFAND', 'HELLIER', 'HENRIKSEN', 'HERCZEG',
#        'HESTER', 'HICKS', 'HIDALGO', 'HILLIER', 'HILTON', 'HINTON',
#        'HLAVACEK-LARRONDO', 'HO', 'HOFNER', 'HOLT', 'HOMAN', 'HOOGERWERF',
#        'HORNSCHEMEIER', 'HOUCK', 'HOWELL', 'HUANG', 'HUBRIG', 'HUDSON',
#        'HUELAMO', 'HUENEMOERDER', 'HUENSCH', 'HUGHES', 'HUI', 'HUMPHREY',
#        'HURLEY', 'HUSSAIN', 'HWANG', 'HYNES', 'IGNACE', 'III', 'IMMLER',
#        'INADA', 'IRWIN', 'ISOBE', 'ISRAEL', 'IWASAWA', 'JENKINS', 'JENSEN',
#        'JERIUS', 'JERNIGAN', 'JESTER', 'JETHA', 'JIMENEZ-GARATE',
#        'JOHNSON', 'JOHNSTONE', 'JONES', 'JONKER', 'JOY', 'JR.', 'JUETT',
#        'KAARET', 'KAASTRA', 'KAHN', 'KALLMAN', 'KAMITSUKASA', 'KAPLAN',
#        'KARGALSTEV', 'KARGALTSEV', 'KAROVSKA', 'KASHYAP', 'KASPI',
#        'KASTNER', 'KATAOKA', 'KATAYAMA', 'KATO', 'KATSUDA', 'KAUFMANN',
#        'KAVANAGH', 'KEEK', 'KEEL', 'KELLOGG', 'KEMPNER', 'KENNEY',
#        'KEOHANE', 'KERKWIJK', 'KERP', 'KHARB', 'KHOSROSHAHI', 'KILIC',
#        'KIM', 'KING', 'KISHIMOTO', 'KLEIN-WOLT', 'KLIS', 'KLOCHKOV',
#        'KOBAYASHI', 'KOBULNICKY', 'KOCHANEK', 'KOMOSSA', 'KONG',
#        'KONOPELKO', 'KOO', 'KOSS', 'KOTOKU', 'KOUVELIOTOU', 'KOYAMA',
#        'KRAEMER', 'KRAFT', 'KRASNOPOLSKY', 'KRAWCZYNSKI', 'KRISS',
#        'KRONGOLD', 'KRUMPE', 'KUHN', 'KUIPER', 'KULKARNI', 'KUNDU',
#        'KUNERT-BAJRASZEWSKA', 'KUNTZ', 'KURASZKIEWICZ', 'KUULKERS', 'LACY',
#        'LAFFON', 'LAL', 'LAMASSA', 'LANDT', 'LANZ', 'LAURENT-MUEHLEISEN',
#        'LAYCOCK', 'LAZENDIC', 'LAZIO', 'LEAHY', 'LEE', 'LEHMER', 'LEIGHLY',
#        'LEUTENEGGER', 'LEVAN', 'LEVENSON', 'LEVINE', 'LEWIN', 'LEWIS',
#        'LEYDER', 'LI', 'LIEDAHL', 'LIN', 'LINARES', 'LINDEN', 'LINSKY',
#        'LIRA', 'LISSE', 'LISTER', 'LIU', 'LLOYD-DAVIES', 'LOARING',
#        'LOBBAN', 'LOEWENSTEIN', 'LOHFINK', 'LOISEAU', 'LONG', 'LONGINOTTI',
#        'LOPEZ', 'LORIMER', 'LOVISARI', 'LOWELL', 'LU', 'LUBIN', 'LUCA',
#        'LUO', 'LUTOVINOV', 'MACCARONE', 'MACHACEK', 'MADEJSKI', 'MAEDA',
#        'MAHDAVI', 'MAIOLINO', 'MAKSYM', 'MALHOTRA', 'MALONEY', 'MAMON',
#        'MANTZ', 'MAOZ', 'MARCO', 'MARELLI', 'MARGON', 'MARGUTTI',
#        'MARKEVITCH', 'MARKOWITZ', 'MARKWARDT', 'MARSCHER', 'MARSHALL',
#        'MARTIN', 'MARTINI', 'MAS-HESSE', 'MASETTI', 'MASSA', 'MASSARDI',
#        'MASSARO', 'MATHUR', 'MATSUMOTO', 'MATT', 'MAUCHE', 'MAUERHAN',
#        'MAUGHAN', 'MAX', 'MAZZOTTA', 'MCCLINTOCK', 'MCCOLLOUGH', 'MCCRAY',
#        'MCDONALD', 'MCDOWELL', 'MCGOWAN', 'MCHARDY', 'MCLAUGHLIN',
#        'MCNAMARA', 'MEIBOM', 'MELIS', 'MENDEZ', 'MEREGHETTI', 'MEYER',
#        'MICELA', 'MICELI', 'MIDDLETON', 'MIGLIARI', 'MIHARA',
#        'MILISAVLJEVIC', 'MILLER', 'MINESHIGE', 'MINGO', 'MINIUTTI',
#        'MIRABAL', 'MISANOVIC', 'MIYAJI', 'MOHR', 'MONTEZ', 'MONTMERLE',
#        'MORAN', 'MORI', 'MORRIS', 'MOTCH', 'MUKAI', 'MULCHAEY', 'MULLIS',
#        'MUNO', 'MURAKAMI', 'MURGIA', 'MURPHY', 'MURRAY', 'MUSHOTZKY',
#        'MUSIELAK', 'NAKAJIMA', 'NAMIKI', 'NAN', 'NANDRA', 'NAZE',
#        'NEILSEN', 'NEINER', 'NELSON', 'NESS', 'NETZER', 'NG', 'NICASTRO',
#        'NORIEGA-CRESPO', 'NOUSEK', 'NOWAK', 'NULSEN', "O'CONNELL", "O'DEA",
#        "O'SULLIVAN", 'OEY', 'OFEK', 'OGELMAN', 'OGLE', 'OGREAN', 'OGURI',
#        'OHASHI', 'OJHA', 'ORIO', 'OSKINOVA', 'OSTEN', 'OTA', 'OTTERBEIN',
#        'OWEN', 'OZEL', 'PACAUD', 'PADOVANI', 'PAERELS', 'PAIZIS',
#        'PALOMBARA', 'PANDEL', 'PANESSA', 'PANNUTI', 'PAPITTO', 'PARDO',
#        'PAREDES', 'PARK', 'PARKINSON', 'PATNAUDE', 'PATRUNO', 'PAVAN',
#        'PAVLOV', 'PEACOCK', 'PEDERSEN', 'PELLEGRINI', 'PENTERICCI',
#        'PEREZ-TORRES', 'PERLMAN', 'PESCE', 'PETIT', 'PETRE', 'PICONCELLI',
#        'PIERRE', 'PIETSCH', 'PILLITTERI', 'PIRES', 'PIRO', 'PITTARD',
#        'PLOTKIN', 'PLUCINSKY', 'POGGE', 'POLLOCK', 'PONMAN', 'PONTI',
#        'POOLEY', 'POPPENHAEGER', 'POSSELT', 'POTTSCHMIDT', 'POVICH',
#        'PRAVDO', 'PREDEHL', 'PREIBISCH', 'PRESTWICH', 'PRIDDEY', 'PRIMINI',
#        'PRINCIPE', 'PTAK', 'PUEHLHOFER', 'QUATAERT', 'RAASSEN', 'RACUSIN',
#        'RAFFERTY', 'RAHMAN', 'RAKOWSKI', 'RAMSAY', 'RANDALL', 'RANGELOV',
#        'RAPPAPORT', 'RASMUSSEN', 'RAUCH', 'RAUW', 'RAY', 'RAYCHAUDHURY',
#        'RAYMOND', 'REA', 'READ', 'REEVES', 'REIG', 'REINES', 'REINSCH',
#        'REIPRICH', 'REIPURTH', 'REMILLARD', 'RENAUD', 'REVNIVTSEV',
#        'REYNOLDS', 'RHO', 'RIAZ', 'RIBAS', 'RIBO', 'RICCI', 'RICHARDS',
#        'RICKER', 'RIECHERS', 'RIEKE', 'RIGBY', 'RISALITI', 'ROBBA',
#        'ROBERTS', 'ROBRADE', 'ROL', 'ROMANI', 'ROMER', 'ROSATI', 'ROSE',
#        'ROSSETTI', 'ROTHSCHILD', 'ROWELL', 'ROZO', 'RUDNICK', 'RUPEN',
#        'RUSSELL', 'RUTLEDGE', 'RYKOFF', 'SAAR', 'SACCO', 'SAEZ',
#        'SAFI-HARB', 'SAHAI', 'SAKAMOTO', 'SAKELLIOU', 'SAKO', 'SALVO',
#        'SALZ', 'SALZER', 'SAMBRUNA', 'SANDERS', 'SANDERSON', 'SANTOS',
#        'SANTOS-LLEO', 'SANWAL', 'SANZ-FORCADA', 'SARAZIN', 'SASAKI',
#        'SATYAPAL', 'SCHARF', 'SCHAWINSKI', 'SCHECHTER', 'SCHINDLER',
#        'SCHIRMER', 'SCHLEGEL', 'SCHMIDT', 'SCHMITT', 'SCHNEIDER', 'SCHULZ',
#        'SCHWARTZ', 'SCIORTINO', 'SCOTT', 'SELL', 'SEWARD', 'SHANKS',
#        'SHELTON', 'SHEMMER', 'SHEN', 'SHIELDS', 'SHU', 'SIEMIGINOWSKA',
#        'SILVERMAN', 'SIMIONESCU', 'SIMON', 'SIVAKOFF', 'SKILLMAN',
#        'SKINNER', 'SLANE', 'SLAVIN', 'SMAIL', 'SMITH', 'SNOW', 'SNOWDEN',
#        'SODERBERG', 'SOKOLOSKI', 'SOLDI', 'SOLERI', 'SORIA', 'SPEYBROECK',
#        'STANFORD', 'STAPPERS', 'STARRFIELD', 'STATLER', 'STAUFFER',
#        'STAWARZ', 'STEFANO', 'STEINER', 'STELLA', 'STELZER', 'STERN',
#        'STEVENS', 'STOCKE', 'STOCKTON', 'STRADER', 'STRATEVA', 'STRAUSS',
#        'STRICKLAND', 'STROHMAYER', 'STRUB', 'SU', 'SUGIHO', 'SUN',
#        'SURACE', 'SUTTON', 'SWANK', 'SWARTZ', 'SZENTGYORGYI', 'SZKODY',
#        'TAKAHASHI', 'TAKEI', 'TAN', 'TANAKA', 'TANANBAUM', 'TAVECCHIO',
#        'TEESELING', 'TEMIM', 'TENNANT', 'TERADA', 'TERASHIMA', 'TERRIER',
#        'TESTA', 'THEILING', 'THOMPSON', 'THUAN', 'TIBOLLA', 'TIENGO',
#        'TOMBESI', 'TOMSICK', 'TORREJON', 'TOWNSLEY', 'TOZZI', 'TREMBLAY',
#        'TREMONTI', 'TREU', 'TRIGO', 'TRIMBLE', 'TRINCHIERI', 'TROJA',
#        'TSUBOI', 'TSUJIMOTO', 'TSUNEMI', 'TSURUTA', 'TUELLMANN', 'TURNER',
#        'TURNSHEK', 'UCHIYAMA', 'UEDA', 'ULMER', 'URRY', 'UTTLEY',
#        'VALENCIC', 'VANSPEYBROECK', 'VASISHT', 'VEILLEUX', 'VERBUNT',
#        'VESTRAND', 'VIEIRA', 'VIGNALI', 'VIKHLININ', 'VINK', 'VIRANI',
#        'VRIES', 'VRTILEK', 'WACHTER', 'WAITE', 'WALDRON', 'WALKER',
#        'WALLIN', 'WALTER', 'WALTON', 'WANG', 'WARD', 'WARGELIN', 'WEAVER',
#        'WEEREN', 'WEGNER', 'WEHRLE', 'WEINTRAUB', 'WEISSKOPF', 'WELSH',
#        'WEN-FAI', 'WERNER', 'WHEATLEY', 'WHELAN', 'WHITE', 'WIJNANDS',
#        'WIK', 'WILKES', 'WILLIAMS', 'WILLIGER', 'WILMS', 'WILSON',
#        'WINKLER', 'WINSTON', 'WISE', 'WOJDOWSKI', 'WOLFF', 'WOLK',
#        'WOLTER', 'WONG', 'WOOD', 'WOODS', 'WORRALL', 'WRIGHT', 'XIA',
#        'XIANG', 'XUE', 'YAMAGUCHI', 'YAMAUCHI', 'YAN', 'YANG', 'YAQOOB',
#        'YATSU', 'YOUNG', 'YU', 'YUAN', 'YUSEF-ZADEH', 'ZABLUDOFF',
#        'ZAKAMSKA', 'ZAND', 'ZAPPACOSTA', 'ZAUDERER', 'ZAVLIN', 'ZEPF',
#        'ZEZAS', 'ZHANG', 'ZHEKOV', 'ZHURAVLEVA', 'ZUCKERMAN', 'ZWART'], dtype=object)
