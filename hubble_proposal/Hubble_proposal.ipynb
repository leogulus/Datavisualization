# %%
# %matplotlib inline 

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import re
import pickle

from matplotlib import rcParams

#these colors come from colorbrewer2.org. Each is an RGB triplet
dark2_colors = [(0.10588235294117647, 0.6196078431372549, 0.4666666666666667),
                (0.8509803921568627, 0.37254901960784315, 0.00784313725490196),
                (0.4588235294117647, 0.4392156862745098, 0.7019607843137254),
                (0.9058823529411765, 0.1607843137254902, 0.5411764705882353),
                (0.4, 0.6509803921568628, 0.11764705882352941),
                (0.9019607843137255, 0.6705882352941176, 0.00784313725490196),
                (0.6509803921568628, 0.4627450980392157, 0.11372549019607843),
                (0.4, 0.4, 0.4)]

rcParams['figure.figsize'] = (10, 6)
rcParams['figure.dpi'] = 150
rcParams['axes.color_cycle'] = dark2_colors
rcParams['lines.linewidth'] = 2
rcParams['axes.grid'] = True
rcParams['axes.facecolor'] = '#eeeeee'
rcParams['font.size'] = 14
rcParams['patch.edgecolor'] = 'none'

def remove_border(axes=None, top=False, right=False, left=True, bottom=True):
    """
    Minimize chartjunk by stripping out unnecesasry plot borders and axis ticks
    
    The top/right/left/bottom keywords toggle whether the corresponding plot border is drawn
    """
    ax = axes or plt.gca()
    ax.spines['top'].set_visible(top)
    ax.spines['right'].set_visible(right)
    ax.spines['left'].set_visible(left)
    ax.spines['bottom'].set_visible(bottom)
    
    #turn off all ticks
    ax.yaxis.set_ticks_position('none')
    ax.xaxis.set_ticks_position('none')
    
    #now re-enable visibles
    if top:
        ax.xaxis.tick_top()
    if bottom:
        ax.xaxis.tick_bottom()
    if left:
        ax.yaxis.tick_left()
    if right:
        ax.yaxis.tick_right()
        
pd.set_option('display.width', 500)
pd.set_option('display.max_columns', 100)

# %% [raw]
# Prop. Type: ENG/STIS/P
# Category:
# ID:         10000
# Cycle:      12
# Title:	    STIS Pure Parallel Imaging Program: Cycle 12
# PI:         Paul Goudfrooij
#
# This is the default archival pure parallel program for STIS during cycle 12.
# ------------------------------------------------------------------------------
# Prop. Type: GO
# Category:   GALAXIES
# ID:         10001
# Cycle:      12
# Title:	    Locating Ultraluminous X-Ray Sources
# PI:         Philip Kaaret
#
# We propose to observe ultraluminous X-ray sources which are located near
# objects bright both in the X-rays and the optical using Chandra and HST. The
# presence of these reference objects will allow us to tie the x-ray and optical
# references frames and achieve 0.1-0.2 arcsecond relative position accuracy in
# searching for optical counterparts to the ultraluminous x-ray sources. This
# will be a significant improvement over the accuracy previously obtained for
# most ULXs {limited by Chandra's absolute astrometry} and will should permit
# identification of individual counterparts.
# ------------------------------------------------------------------------------
# Prop. Type: GO
# Category:   AGN
# ID:         10002
# Cycle:      12
# Title:	    Detailed Study of X-ray Jets from a Complete Survey
# PI:         Eric Perlman
#
# We propose deep followup HST and Chandra observations of two X-ray jets, which
# are the X-ray brightest discovered in our Chandra survey of quasars with known
# radio jets. With these data, we will compare their X-ray, optical and radio
# morphologies. We will also obtain X-ray and optical spectral indices, and
# spatially resolved SEDs from the radio through the X-rays. This will allow us
# to determine the X-ray emission mechanism at each point in these jets, and
# test critical predictions made by each mechanism. We will also be able to
# track any changes in physical conditions {including magnetic field and bulk

# %%
index=0
prop,cat,ids,cycle,title,pi=[],[],[],[],[],[]
abst0 = [[] for _ in range(12000)]
lines=[]
with open("abstracts.cat") as infile:
    for i, line in enumerate(infile):
        lines.append(line)
        if i==32934:
            pass
        elif line.startswith('Prop. Type:'):
            prop.append(line[12:].rstrip())
        elif line.startswith('Category:'):
            cat.append(line[12:].rstrip())
        elif line.startswith('ID:   '):
            ids.append(line[12:].rstrip())
        elif line.startswith('Cycle:'):
            cycle.append(line[12:].rstrip())
        elif line.startswith('Title:'):
            title.append(line[11:].rstrip())
        elif line.startswith('\t'):
            title[-1]=title[-1]+' '+line[5:].rstrip()
        elif line.startswith('PI:'):
            pi.append(line[12:].rstrip())
        elif line.startswith('------------------------------------------------------------------------------\n'):
            index+=1
        else: 
            abst0[index].append(line.rstrip())
            
abst1 = [x for x in abst0 if x != []]            
abstr=[" ".join(ab) for ab in abst1]

len(prop),len(cat),len(ids),len(cycle),len(title),len(pi),len(abstr)

df=pd.DataFrame({'prop_type':prop,'category':cat,'id':ids,'cycle':cycle,'title':title,'pi':pi,'abstract':abstr})

# %%
a=-2
prop[a], cat[a], ids[a], cycle[a], title[a], pi[a], abstr[a]
# Out:
# ('CAL/NIC',
#  '',
#  '9998',
#  '12',
#  'NICMOS Cycle 12 Grism Calibration and Standard Stars to 2.5microns',
#  'Ralph Bohlin',
#  ' This is the grism calibration proposal.')

# %%
df['prop_type'].unique()
# Out:
# array(['ENG/STIS/P', 'GO', 'CAL/AST', 'CAL/OTA', 'CAL/STIS', 'ENG/STIS',
#        'GO/DD', 'CAL/ACS', 'CAL/NIC', 'CAL/WF2', 'GO/PAR', 'SNAP',
#        'GTO/AST', 'GTO/OS', 'AR', 'GTO/FOS', 'GTO/ACS', 'ENG/SC',
#        'ENG/ACS', 'ENG/NIC', 'ENG/FGS', 'NASA', 'ENG/WF2', 'GTO/HSP',
#        'GTO/WFC', 'SM4/SC', 'ENG/AST', 'SM4/STIS', 'SM4/COS', 'SM4/WFC3',
#        'SM4/ACS', 'GTO/HRS', 'SM4/NIC', 'AUG/HRS', 'SM4/FGS', 'SM4/ERO',
#        'ENG/COS', 'GTO/COS', 'CAL/COS', 'CAL/WFC3', 'ENG/WFC3', 'GTO/FOC',
#        'SV/FOS', 'SV/WFC', 'SV/OLT', 'OV/HRS', 'SV/HRS', 'OV/HSP', 'OV',
#        'SV/HSP', 'SV/AST', 'OV/WFC', 'OV/FOS', 'OV/FOC', 'SV/FOC',
#        'OV/OTA', 'OV/OLT', 'GST-5', 'GST/FOS', 'GST/AST', 'GST/WFC',
#        'OV/GHRS', 'GST7', 'SV/MSC', 'GO/AM', 'CAL/FOC', 'CAL/FOS',
#        'CAL/HRS', 'CAL/WFC', 'EROS', 'CAL/HSP', 'SV/GHRS', 'SAT/FOC',
#        'SAT/FOS', 'SAT/AST', 'SAT/HSP', 'SAT/WFC', 'SAT/HRS', 'SNAP/SAT',
#        'ERO/FOC', 'SV/OTA', 'SAT/OS', 'ENG', 'OV/AST', 'ENG/FOS',
#        'ENG/OTA', 'SV', 'SV/WFPC', 'ENG/WFC', 'ENG/HRS', 'RPT/FOC',
#        'RPT/FOS', 'RPT/WFC', 'ENG/FOC', 'AUG/OS', 'AUG/FOC', 'AUG/WFC',
#        'RPT/GO', 'RPT/OS', 'RPT/HRS', 'AUG/FOS', 'RPT/GTO', 'CAL/FGS',
#        'SMC/HRS', 'SMC/FOS', 'SMC/FOC', 'SMC/WF2', 'GO/AST', 'SMC/OTA',
#        'SME/PCS', 'SME/WF2', 'SMC/COS', 'ENG/HSP', 'SME/HRS', 'ENG/OLT',
#        'SME/FOS', 'SME/MOC', 'RPT/HSP', 'SME/COS', 'AUG/HSP', 'SMC/ENG',
#        'AST', 'SME/FOC', 'SMC/ERO', 'GTO/WF2', 'SME/OTA', 'GO/RPT',
#        'ENG/MT', 'GO/CAR', 'AUG/WF2', 'TEST', 'OSG/OTA', 'SM2/FGS',
#        'SM2/PCS', 'SM2/COS', 'SM2/FOC', 'SMOV', 'SM2/WF2', 'SM2/NIC',
#        'SM2/STIS', 'SM2/ERO', 'GTO/NIC', '', 'GTO/STIS', 'CAL',
#        'CAL/NIC/PA', 'CAL/PAR', 'SM3/WF2', 'SM3/ERO', 'SM3/STIS', 'SM3/SC',
#        'SM3/FGS', 'SM3/NIC', 'SM3/ACS', 'SM3/NIC/PA', 'GO/DD/PAR'], dtype=object)

# %%
df.prop_type.value_counts()
# Out:
# GO            5263
# AR             905
# CAL/STIS       432
# GO/DD          409
# SNAP           339
# CAL/WFC3       305
# CAL/ACS        257
# CAL/WF2        175
# CAL/NIC        159
# CAL/COS        127
# GTO/STIS       106
# CAL/AST        106
# GTO/HRS        104
# CAL/WFC         99
# GTO/OS          90
# GO/CAR          87
# CAL/HRS         84
# CAL/FOC         78
# GTO/FOS         76
# GO/PAR          71
# GTO/AST         68
# CAL/FOS         64
# GTO/WF2         63
# GTO/FOC         63
# GTO/HSP         60
# GTO/WFC         59
# SM2/STIS        58
# GTO/NIC         54
# CAL/OTA         52
# GTO/ACS         52
#               ...
# SAT/HSP          2
# ERO/FOC          2
# ENG/WFC          2
#                  2
# CAL/PAR          1
# RPT/GTO          1
# SV/WFPC          1
# OV/GHRS          1
# ENG/MT           1
# SV/GHRS          1
# SM3/NIC/PA       1
# SV               1
# OV/OLT           1
# GO/AST           1
# SAT/AST          1
# GST/AST          1
# GST/WFC          1
# GST-5            1
# SV/OTA           1
# CAL/FGS          1
# CAL              1
# RPT/OS           1
# SMC/ENG          1
# GO/RPT           1
# AST              1
# ENG/HSP          1
# SME/MOC          1
# OSG/OTA          1
# GST/FOS          1
# ENG/WFC3         1
# Name: prop_type, dtype: int64

# %%
df2=df.loc[[i.startswith('G') or i.startswith('A') for i in df.prop_type.values],:]; df2
# Out:
#                                                 abstract                      category cycle     id                   pi  prop_type                                              title
# 1       We propose to observe ultraluminous X-ray sou...                      GALAXIES    12  10001        Philip Kaaret         GO               Locating Ultraluminous X-Ray Sources
# 2       We propose deep followup HST and Chandra obse...                           AGN    12  10002         Eric Perlman         GO  Detailed Study of X-ray Jets from a Complete S...
# 3       We propose 4 new Chandra observations of NGC4...                      GALAXIES    12  10003        Craig Sarazin         GO  Deep Chandra and Hubble Observations of NGC469...
# 4       Extended jets have been a key target for Chan...                           AGN    12  10004         F. Tavecchio         GO  The Physics of Relativistic Jets: Chandra Imag...
# 5       We propose to extend our ongoing studies of t...                      GALAXIES    12  10005         Walter Lewin         GO  A Uniform Study of Globular Cluster X-raySourc...
# 6       During A01-3 we found 22 Black Hole X-ray Nov...                      GALAXIES    12  10006       Michael Garcia         GO                      Black Hole X-ray Novae in M31
# 7       We propose to obtain the first high-quality, ...                     HOT STARS    12  10007       Michael Garcia         GO        The Spectral Energy Distribution of Cen X-4
# 8       We propose two HST orbits, nearly simultaneou...                      GALAXIES    12  10008    Jonathan Grindlay         GO  The Supersoft Source 1E1339.8+2837 and Globula...
# 9       We propose a deep survey in the second lowest...                      GALAXIES    12  10009    Jonathan Grindlay         GO                         Galactic Bulge Deep Survey
# 41      Our recent discovery of a planetary-sized bod...                  SOLAR SYSTEM    12  10041        Michael Brown      GO/DD  Characterization of a planetary-sized body in ...
# 65      We will take highest-quality HST images of Ma...                  SOLAR SYSTEM    12  10065           James Bell      GO/DD                           Mars at Closest Approach
# 81      Using HST Lyman alpha observations, we have d...                                  12  10081  Alfred Vidal-Madjar      GO/DD  Is the exoplanet HD209458b's exosphere in a bl...
# 82      This is a POMS test proposal designed to simu...                                  12  10082         James Rhoads     GO/PAR              WFII backup parallel archive proposal
# 83      A key measurement goal of the Cassini mission...                  SOLAR SYSTEM    12  10083          John Clarke      GO/DD  HST UV Images of Saturn's Aurora Coordinated w...
# 84      This is the generic target version of the WFP...                                  12  10084         James Rhoads     GO/PAR                     WFII parallel archive proposal
# 86      The ACS Ultra Deep Field {UDF} is a survey ca...                                  12  10086      Steven Beckwith      GO/DD                      The Ultra Deep Field with ACS
# 88      We propose a 300~ks HETGS observation simulta...                   AGN/QUASARS    12  10088            Julia Lee         GO  A Chandra HETGS & HST view of the Warm and Luk...
# 89      We will obtain a spectacular color image of t...                                  12  10089           Keith Noll      GO/DD  Hubble Heritage Image of the Light Echo around...
# 90      This is a POMS test proposal designed to simu...                                  12  10090         James Rhoads     GO/PAR              WFII backup parallel archive proposal
# 91      Chandra Observations of Mira AB symbiotic-lik...                                  12  10091   Margarita Karovska      GO/DD                    Soft X-ray Transient in Mira AB
# 92      We will undertake a 2 square degree imaging s...                     COSMOLOGY    13  10092    Nicholas Scoville         GO                     The COSMOS 2-Degree ACS Survey
# 94      We propose a three-year program to provide bo...           STELLAR POPULATIONS    13  10094        Ruth Peterson         GO  Mid-Ultraviolet Spectral Templates for Old Ste...
# 95      This proposal observes Comet Tempel-1 near th...                                  12  10095           Keith Noll      GO/DD  Hubble Heritage Observations of Deep Impact Ta...
# 98      Type Ia supernovae are of key importance in c...  ISM AND CIRCUMSTELLAR MATTER    13  10098  Pilar Ruiz-Lapuente         GO  Probing the nature of Type Ia SNe through HST ...
# 99      The distances to neutron stars are a fundamen...                     HOT STARS    13  10099     Frederick Walter         GO                            The Parallax of Geminga
# 100     The carbon star V Hydrae is experiencing heav...                    COLD STARS    13  10100     Raghvendra Sahai         GO  Tracking the Evolution of a Knotty, High- Spee...
# 101     We propose a photometric study of the lower m...                    COLD STARS    13  10101            Ivan King         GO  The Region of the Hydrogen-Burning Limit in Om...
# 102     Last year, our Uranian ring and moon observin...                  SOLAR SYSTEM    13  10102       Mark Showalter         GO  Rings of Uranus: Dynamics, Particle Properties...
# 103     We propose observations with HST/FGS to deter...                                  13  10103      George Benedict         GO  FGS Astrometry of a Star Hosting an Extrasolar...
# 104     We propose to use HST-FGS1R to calibrate the ...                    COLD STARS    13  10104           Todd Henry         GO  Calibrating the Mass-Luminosity Relation at th...
# ...                                                  ...                           ...   ...    ...                  ...        ...                                                ...
# 11167   In Cycle 8 we initiated a WFPC2 snapshot surv...                     HOT STARS    12   9964          Howard Bond         GO  Dynamical Masses of White Dwarfs from Resolved...
# 11168   We propose to measure the expansion parallax ...  ISM AND CIRCUMSTELLAR MATTER    12   9965       Romano Corradi         GO  Expansion distances to the symbiotic Miras He ...
# 11169   In 1996, we reported the discovery of a brigh...                     HOT STARS    12   9966      Laurent Drissen         GO  Physical Parameters of the Erupting Luminous B...
# 11170   Quantitative understanding of classical Cephe...                    COLD STARS    12   9967          Nancy Evans         GO  Cepheid Masses: U Aql {Cycle 12 continuation o...
# 11171   We propose to characterize the physical prope...                    COLD STARS    12   9968       Eduardo Martin         GO  Fundamental properties of L-type dwarfs in bin...
# 11172   We propose observations with HST/FGS in Posit...                    COLD STARS    12   9969      George Benedict         GO  FGS Astrometry of the Extrasolar Planet of Eps...
# 11173   The analysis of over 30 yr of 161 eclipse tim...                    COLD STARS    12   9970        Edward Guinan         GO  The Best Brown Dwarf Yet?: FGS Astrometry of t...
# 11174   We propose observations with HST/FGS to deter...                                  12   9971      George Benedict         GO  FGS Astrometry of a Star Hosting an Extrasolar...
# 11175   We propose to use HST-FGS1R to calibrate the ...                                  12   9972           Todd Henry         GO  Calibrating the Mass-Luminosity Relation at th...
# 11176   For a variety of reasons, HST can provide a v...                                  12   9973        Kris Davidson         GO  Intensive Coverage of the Eta Carinae Event in...
# 11177   We propose a three-year program to provide bo...                                  12   9974        Ruth Peterson         GO  Mid-Ultraviolet Spectral Templates for Old Ste...
# 11178   We propose to utilize the unique UV capabilit...                  SOLAR SYSTEM    12   9975         Philip James         GO  Ozone, Condensates, and Dust in the Martian At...
# 11179   We propose to measure the parallax of two nea...                                  12   9976         David Kaplan         GO  The Parallaxes and Proper Motions of Two Nearb...
# 11180   Determining the composition of the dark matte...                                  12   9977        David Bennett         GO  Gravitational Microlensing in the NGC 3314A-B ...
# 11181   The ACS Ultra Deep Field {UDF} is a survey ca...                                  12   9978      Steven Beckwith      GO/DD                      The Ultra Deep Field with ACS
# 11182   This is a plan to manage the NICMOS pure para...                                  12   9979      Steven Beckwith  GO/DD/PAR            The Ultra Deep Field - NICMOS Parallels
# 11183   The ACS Ultra Deep Field {UDF} is a survey ca...                                  12   9980      Steven Beckwith  GO/DD/PAR             The Ultra Deep Field - WFPC2 Parallels
# 11184   We propose to obtain slitless spectroscopy of...                                  12   9981      Steven Beckwith  GO/DD/PAR              The Ultra Deep Field - STIS parallels
# 11185   We propose to measure the UV energy distribut...                                  11   9982       Dieter Reimers      GO/DD  Intergalactic-Ionized Helium toward HS 1700+64...
# 11186   Ring galaxies are an aesthetically captivatin...                                  11   9983           Keith Noll      GO/DD  Hubble Heritage Observations of Ring Galaxy AM...
# 11187   Small distortions in the shapes of background...                                  11   9984         Jason Rhodes     GO/PAR               Cosmic Shear With ACS Pure Parallels
# 11188   Our target of opportunity program aims at und...                                  12   9985         Holland Ford    GTO/ACS                      Comets: Gas in the Inner Coma
# 11189   This program is a continuation of the Cycle 1...                                  12   9986         Holland Ford    GTO/ACS         Massive Black Holes in Early Type Galaxies
# 11190   We will use the coronagraphic and imaging mod...                                  12   9987         Holland Ford    GTO/ACS  Coronagraphic search for disks around nearby s...
# 11191   The icy Galilean satellites form an integral ...                                  12   9988         Holland Ford    GTO/ACS                                  Jovian Satellites
# 11192   Starbursts are ideally suited to study the ev...                                  12   9989         Holland Ford    GTO/ACS  Starburst Galaxies and Their Population of Sup...
# 11193   Cycle 11 NICMOS images of LHS 102B {Program 9...                                  12   9990         Holland Ford    GTO/ACS  Investigating the multiplicity of the L dwarf ...
# 11194   We have recently discovered a binary companio...                                  11   9991           Keith Noll      GO/DD  The Orbit of a Newly Discovered Transneptunian...
# 11195   We request Director's discretionary time to a...                           ISM    12   9992      Robert Kirshner      GO/DD                 Essential Observations of SN 1987A
# 11202   The COSMOS 2-Degree ACS Survey NICMOS Paralle...                     COSMOLOGY    12   9999    Nicholas Scoville     GO/PAR    The COSMOS 2-Degree ACS Survey NICMOS Parallels
#
# [7736 rows x 7 columns]

# %%
df.loc[['Frebel' in i for i in df.pi.values],:]
# Out:
#                                                abstract    category cycle     id           pi prop_type                                              title
# 1745   We propose to obtain near-UV HST/STIS spectro...  COOL STARS    17  11668  Anna Frebel        GO  Cosmo-chronometry and Elemental Abundance Dist...
# 3399   Relatively little is known about the chemical...  COOL STARS    21  13246  Anna Frebel        AR  The nucleosynthetic origins and chemical evolu...
# 4345   The nucleosynthetic signatures of the first s...  COOL STARS    23  14151  Anna Frebel        GO  Constraining Pop III supernova energies and th...

# %%
print df.loc[df.prop_type=='ENG/MT','abstract'].values
# Out:
# [ '  Simple guidestar handoff (SGSH) capability was delivered as part of SOGS build 32.0. This proposal will test SGSH on HST by making one PC iimage of a fast-moving asteroid, doing a handoff procedure, and repeating the image. Any drift in the asteroid position between the two images will be compared to the SOGS prediction. If the drift is greater, the SESD MOVT team will attempt to determine the reason and rectify the problem before operational use of this procedure.']

# %%
for i in df.loc[:,'pi'].unique()[0:10]:
    print i
# Out:
# Paul Goudfrooij
# Philip Kaaret
# Eric Perlman
# Craig Sarazin
# F. Tavecchio
# Walter Lewin
# Michael Garcia
# Jonathan Grindlay
# Edmund Nelan
# Stefano Casertano

# %%
names=df2.loc[:,'pi'].unique(); print names, len(names)
# Out:
# ['Philip Kaaret' 'Eric Perlman' 'Craig Sarazin' ..., 'Alister Graham'
#  'Alex Lazarian' 'Andrew Phillips'] 2037

# %%
outname='author_list_r.pickle'
pickle.dump(names, open(outname , "wb" ) )
print outname
# Out:
# author_list_r.pickle
