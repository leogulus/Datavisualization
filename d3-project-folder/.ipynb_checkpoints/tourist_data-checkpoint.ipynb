# %%
import pickle
import csv

list2 = []
f = open('data1.csv', 'rt')
try:
    reader = csv.reader(f)
    for row in reader:
        list2.append(row)
finally:
    f.close()

# %%
list2[2] == 'Arrivals - Thousands'
# Out:
# ['Arrivals - Thousands', '..']

# %%
d = {}
for i in list2:
    if i[0].isupper():
        print i[0]
    elif i[0] == 'Arrivals - Thousands':
        print i[1]
# Out:
# AFGHANISTAN
# ..
# ALBANIA
# 3,256
# 2,857
# 118
# ALGERIA
# ..
# AMERICAN SAMOA
# ..
# ANDORRA
# 2,335
# ANGOLA
# 650
# ANGUILLA
# 69
# ANTIGUA AND BARBUDA
# 244
# ARGENTINA
# 5,571
# ARMENIA
# 1,084
# ARUBA
# 979
# AUSTRALIA
# 6,382
# ..
# AUSTRIA
# 24,813
# AZERBAIJAN
# 2,509
# 2,130
# BAHAMAS
# 1,364
# BAHRAIN
# 9,163
# ..
# BANGLADESH
# 148
# BARBADOS
# 509
# BELARUS
# 137
# BELGIUM
# 7,684
# BELIZE
# 294
# BENIN
# 231
# BERMUDA
# 236
# BHUTAN
# 116
# BOLIVIA
# 798
# BONAIRE
# ..
# BOSNIA AND HERZEGOVINA
# 529
# BOTSWANA
# ..
# BRAZIL
# 5,813
# BRITISH VIRGIN ISLANDS
# 366
# BRUNEI DARUSSALAM
# 3,279
# 225
# BULGARIA
# 6,898
# BURKINA FASO
# 218
# BURUNDI
# ..
# CABO VERDE
# 503
# CAMBODIA
# 4,210
# CAMEROON
# 912
#
# CANADA
# 16,590
# CAYMAN ISLANDS
# 345
# CENTRAL AFRICAN REPUBLIC
# ..
# CHAD
# 100
# 32
# CHILE
# 3,576
# CHINA
# 55,686
# COLOMBIA
# 2,595
# 2,288
# COMOROS
# ..
# CONGO
# 305
# 297
# COOK ISLANDS
# 121
# COSTA RICA
# 2,428
# COTE D'IVOIRE
# ..
# ..
# CROATIA
# ...
