# %%
import subprocess
import pickle
import matplotlib.pyplot as plt
import mpld3
import numpy as np
import pandas as pd
from astropy.io import fits
#import seaborn as sns
from statsmodels.graphics.mosaicplot import mosaic

# %matplotlib inline

# %%
df=pd.read_csv('mki_data.csv')

# %%
df=df.replace('n/a', np.nan)
df=df.replace('Repaport','Rapaport')
df
# Out:
#                 Graduated PhD       Area             Supervisor  \
# 0                 Miller, Jon      ASTRX                  Lewin
# 1              Monnelly, Glen      ASTRX                 Ricker
# 2            Morgan, Nicholas      ASTRT              Schechter
# 3               Muno, Michael      ASTRX  Chakrabarty/Remillard
# 4                 Pfahl, Eric      ASTRX              Reppaport
# 5           Sylvestre, Julien      ASTRX                  Weiss
# 6           Butler, Nathaniel      ASTRX       Ricker/Rappaport
# 7              Kasper, Justin      ASTRX                Lazarus
# 8              Lawrence, Ryan      ASTRX                  Weiss
# 9               Pooley, David      ASTRX                  Lewin
# 10          Portsmouth, Jamie      ASTRX           Bertschinger
# 11             Stage, Michael      ASTRX         Canizares/Joss
# 12             Adhikari, Rana      ASTRX        Fritschel/Weiss
# 13               Becker, John      ASTRT                   Joss
# 14  Burgess,Kristen (McBride)      ASTRX            Burles/Guth
# 15              Fregeau, John      ASTRT              Rappaport
# 16             Jeltema, Tesla      ASTRX              Canizares
# 17            Juett, Adrienne      ASTRX            Chakrabarty
# 18           Wang, Zhongxiang      ASTRX            Chakrabarty
# 19               Bolton, Adam      ASTRX                 Burles
# 20         Chatterji, Shourov      ASTRX          Katsavounidis
# 21       Muterspaugh, Matthew      ASTRX                  Burke
# 22         Schnittman, Jeremy      ASTRT           Bertschinger
# 23        Shirokov, Alexander      ASTRT           Bertschinger
# 24            Ballmer, Stefan      ASTRX          Katsavounidis
# 25              Boyce, Edward      ASTRX                 Hewitt
# 26        Gibson, Robert Ross      ASTRT              Canizares
# 27               Bowman, Judd      ASTRX                 Hewitt
# 28           Csatorday, Peter      ASTRX                 Ricker
# 29              Goda, Keisuke      ASTRX              Mavalvala
# ..                        ...        ...                    ...
# 50           Sanderson, Robyn      ASTRT           Bertschinger
# 51                Liu, Adrian      ASTRT                Tegmark
# 52           Matejek, Michael      ASTRX                 Simcoe
# 53             Rogers, Leslie      ASTRT                 Seager
# 54   Smith-Lefebvre, Nicholas      ASTRX              Mavalvala
# 55                 Stein, Leo      ASTRX                 Hughes
# 56            Vigeland, Sarah      ASTRT                 Hughes
# 57      Williams, Christopher      ASTRX                 Hewitt
# 58             Zukin, Phillip      ASTRT           Bertschinger
# 59              Dwyer, Sheila      ASTRX              Mavalvala
# 60             Elkholy, Tamer      ASTRX              Canizares
# 61          Wipf, Christopher      ASTRX              Mavalvala
# 62           Rutherford, John      ASTRX     Figueroa-Feliciano
# 63                 Chen, Carl       EECS           Schattenburg
# 64              Konkola, Paul      MechE           Schattenburg
# 65              Montoya, Juan       EECS           Schattenburg
# 66              Forest, Craig      MechE           Schattenburg
# 67          Akilian, Mireille      MechE           Schattenburg
# 68            Chang, Chih-Hao      MechE           Schattenburg
# 69               Joo, Chulmin      MechE           Schattenburg
# 70                    Mao, Yi        CTP                Tegmark
# 71                 Zhao, Yong      MechE           Schattenburg
# 72              Ahn, Minseung      MechE           Schattenburg
# 73            Hertzberg, Mark        CTP                Tegmark
# 74         Al Husseini, Abdul      MechE           Schattenburg
# 75             Shapiro, Brett      MechE              Mavalvala
# 76              Hertel, Scott      NUPAX     Figueroa-Feliciano
# 77            McCarthy, Kevin      NUPAX     Figueroa-Feliciano
# 78           Bruccoleri, Alex  AeroAstro           Schattenburg
# 79                   Sung, Ed      MechE           Schattenburg
#
#            Supervisor1 Supervisor2 Degree/Year Degree  Year  \
# 0                Lewin         NaN    PhD 2002    PhD  2002
# 1               Ricker         NaN    PhD 2002    PhD  2002
# 2            Schechter         NaN    PhD 2002    PhD  2002
# 3          Chakrabarty   Remillard    PhD 2002    PhD  2002
# 4            Reppaport         NaN    PhD 2002    PhD  2002
# 5                Weiss         NaN    PhD 2002    PhD  2002
# 6               Ricker   Rappaport    PhD 2003    PhD  2003
# 7              Lazarus         NaN    PhD 2003    PhD  2003
# 8                Weiss         NaN    PhD 2003    PhD  2003
# 9                Lewin         NaN    PhD 2003    PhD  2003
# 10        Bertschinger         NaN    PhD 2003    PhD  2003
# 11           Canizares        Joss    PhD 2003    PhD  2003
# 12           Fritschel       Weiss    PhD 2004    PhD  2004
# 13                Joss         NaN    PhD 2004    PhD  2004
# 14              Burles        Guth    PhD 2004    PhD  2004
# 15           Rappaport         NaN    PhD 2004    PhD  2004
# 16           Canizares         NaN    PhD 2004    PhD  2004
# 17         Chakrabarty         NaN    PhD 2004    PhD  2004
# 18         Chakrabarty         NaN    PhD 2004    PhD  2004
# 19              Burles         NaN    PhD 2005    PhD  2005
# 20       Katsavounidis         NaN    PhD 2005    PhD  2005
# 21               Burke         NaN    PhD 2005    PhD  2005
# 22        Bertschinger         NaN    PhD 2005    PhD  2005
# 23        Bertschinger         NaN    PhD 2005    PhD  2005
# 24       Katsavounidis         NaN    PhD 2006    PhD  2006
# 25              Hewitt         NaN    PhD 2006    PhD  2006
# 26           Canizares         NaN    PhD 2006    PhD  2006
# 27              Hewitt         NaN    PhD 2007    PhD  2007
# 28              Ricker         NaN    PhD 2007    PhD  2007
# 29           Mavalvala         NaN    PhD 2007    PhD  2007
# ..                 ...         ...         ...    ...   ...
# 50        Bertschinger         NaN    PhD 2011    PhD  2011
# 51             Tegmark         NaN    PhD 2012    PhD  2012
# 52              Simcoe         NaN    PhD 2012    PhD  2012
# 53              Seager         NaN    PhD 2012    PhD  2012
# 54           Mavalvala         NaN    PhD 2012    PhD  2012
# 55              Hughes         NaN    PhD 2012    PhD  2012
# 56              Hughes         NaN    PhD 2012    PhD  2012
# 57              Hewitt         NaN    PhD 2012    PhD  2012
# 58        Bertschinger         NaN    PhD 2012    PhD  2012
# 59           Mavalvala         NaN    PhD 2013    PhD  2013
# 60           Canizares         NaN    PhD 2013    PhD  2013
# 61           Mavalvala         NaN    PhD 2013    PhD  2013
# 62  Figueroa-Feliciano         NaN    PhD 2013    PhD  2013
# 63        Schattenburg         NaN    PhD 2003    PhD  2003
# 64        Schattenburg         NaN    PhD 2003    PhD  2003
# 65        Schattenburg         NaN    PhD 2006    PhD  2006
# 66        Schattenburg         NaN    PhD 2007    PhD  2007
# 67        Schattenburg         NaN    PhD 2008    PhD  2008
# 68        Schattenburg         NaN    PhD 2008    PhD  2008
# 69        Schattenburg         NaN    PhD 2008    PhD  2008
# 70             Tegmark         NaN    PhD 2008    PhD  2008
# 71        Schattenburg         NaN    PhD 2008    PhD  2008
# 72        Schattenburg         NaN    PhD 2009    PhD  2009
# 73             Tegmark         NaN    PhD 2010    PhD  2010
# 74        Schattenburg         NaN     MS 2011     MS  2011
# 75           Mavalvala         NaN    PhD 2012    PhD  2012
# 76  Figueroa-Feliciano         NaN    PhD 2012    PhD  2012
# 77  Figueroa-Feliciano         NaN    PhD 2013    PhD  2013
# 78        Schattenburg         NaN    PhD 2013    PhD  2013
# 79        Schattenburg         NaN     MS 2013     MS  2013
#
#                             Company Name      Country           Career Type  \
# 0                 University of Michigan          USA              Academic
# 1                            Danske Bank          USA      Outside Industry
# 2        Westport Board of Education, CT          USA                  K-12
# 3                 MIT Lincoln Laboratory          USA  Scientific Research
# 4         Institute for Defense Analyses          USA             Nonprofit
# 5                             IBM Canada       Canada      Outside Industry
# 6               Arizona State University          USA              Academic
# 7                 University of Michigan          USA              Academic
# 8                        MIT-Lincoln Lab          USA  Scientific Research
# 9           Sam Houston State University          USA              Academic
# 10            The Moving Picture Company          USA      Outside Industry
# 11                 Mount Holyoke College          USA              Academic
# 12                               Caltech          USA              Academic
# 13            MGH/Harvard Medical School          USA      Medical Industry
# 14   San Fransicso Paramedic Association          USA      Medical Industry
# 15        Institute for Defense Analyses          USA             Nonprofit
# 16  University of California, Santa Cruz          USA              Academic
# 17                          Metron, Inc.          USA      Outside Industry
# 18     Shanghai Astronomical Observatory        China              Academic
# 19                    University of Utah          USA              Academic
# 20                MIT Lincoln Laboratory          USA  Scientific Research
# 21            Tennessee State University          USA              Academic
# 22                        NASA - Goddard          USA  Scientific Research
# 23    Canadian Imperial Bank of Commerce       Canada      Outside Industry
# 24                    Syracuse Univesity          USA              Academic
# 25                         Origin Energy    Australia      Outside Industry
# 26                           HP Autonomy          NaN      Outside Industry
# 27              Arizona State University          USA              Academic
# 28                        Rbs Securities          USA      Outside Industry
# 29                   University of Tokyo        Japan              Academic
# ..                                   ...          ...                   ...
# 50        Kapteyn Astronomical Institute  Netherlands               Postdoc
# 51                           UC Berkeley          USA               Postdoc
# 52                         Goldman Sachs          USA      Outside Industry
# 53                               Caltech          USA               Postdoc
# 54                          Caltech-LIGO          USA               Postdoc
# 55                    Cornell University          USA               Postdoc
# 56             Jet Propulsion Laboratory          USA               Postdoc
# 57                Harvard Medical School          USA      Medical Industry
# 58                           UC Berkeley          USA               Postdoc
# 59              LIGO Hanford Observatory          USA               Postdoc
# 60                           HP Autonomy          NaN      Outside Industry
# 61                              MIT-LIGO          USA               Postdoc
# 62                              WegoWise          USA      Outside Industry
# 63                Waters Pacific Pte Ltd    Singapore      Outside Industry
# 64                    Eyekon Systems LLC          USA      Outside Industry
# 65                MIT Lincoln Laboratory          USA  Scientific Research
# 66                          Georgia Tech          USA              Academic
# 67               Smith&Nephew, Endoscopy          USA      Outside Industry
# 68                   NC State University          USA              Academic
# 69                    GE Global Research          USA      Outside Industry
# 70     Institut d'Astrophysique de Paris       France               Postdoc
# 71                            UBS London      England      Outside Industry
# 72                                 Intel          USA      Outside Industry
# 73                                   MIT          USA               Postdoc
# 74  NASA, Ames for 3 yrs; currently, MIT          USA  Scientific Research
# 75                   Stanford University          USA               Postdoc
# 76                       Yale University          USA               Postdoc
# 77                 Intellectual Ventures          USA      Outside Industry
# 78                           Izentis LLC          USA      Outside Industry
# 79                          Lam Research          USA      Outside Industry
#
#                                       Title
# 0                       Associate Professor
# 1                  Senior Portfolio Manager
# 2        Physics & Science Research Teacher
# 3                           Technical Staff
# 4                            Research Staff
# 5                        Principal Engineer
# 6                       Assistant Professor
# 7   Associate Professor(also CFA affiliate)
# 8                           Technical Staff
# 9                       Assistant Professor
# 10                    R&D Software Engineer
# 11                      Assistant Professor
# 12                                Professor
# 13                  Instructor in Radiology
# 14                     EMT Program Director
# 15                           Research Staff
# 16                      Assistant Professor
# 17                                  Analyst
# 18                                Professor
# 19                      Assistant Professor
# 20                          Technical Staff
# 21                      Assistant Professor
# 22                           Astrophysicist
# 23                           Senior Analyst
# 24                                Professor
# 25                           Senior Analyst
# 26             Systems Performance Engineer
# 27                      Assistant Professor
# 28                                  Advisor
# 29                                Professor
# ..                                      ...
# 50                  Postdoctoral Researcher
# 51                      Postdoctoral Fellow
# 52                                   Broker
# 53                            Hubble Fellow
# 54                      Postdoctoral Fellow
# 55                          Einstein Fellow
# 56                 NASA Postdoctoral Fellow
# 57                 Medical Physics Resident
# 58                      Postdoctoral Fellow
# 59                                  Postdoc
# 60                    Technology Consultant
# 61                   Postdoctoral Associate
# 62                           Data Scientist
# 63          Senior Engineering Manager(R&D)
# 64                                  Founder
# 65                          Technical Staff
# 66                      Assistant Professor
# 67                     Development Engineer
# 68                      Assistant Professor
# 69                        Optical Scientist
# 70                      Postdoctoral Fellow
# 71                       Associate Director
# 72                  Senior Process Engineer
# 73                      Postdoctoral Fellow
# 74                        MechE PhD program
# 75                     Postdoctoral Scholar
# 76                   Postdoctoral Associate
# 77                         Research Analyst
# 78                                      CEO
# 79                      Mechanical Engineer
#
# [80 rows x 12 columns]

# %%
df2=df.groupby(['Career Type'])

# %%
df2.describe()
# Out:
#                                    Year
# Career Type
# Academic             count    17.000000
#                      mean   2005.235294
#                      std       2.278415
#                      min    2002.000000
#                      25%    2003.000000
#                      50%    2005.000000
#                      75%    2007.000000
#                      max    2010.000000
# K-12                 count     2.000000
#                      mean   2005.000000
#                      std       4.242641
#                      min    2002.000000
#                      25%    2003.500000
#                      50%    2005.000000
#                      75%    2006.500000
#                      max    2008.000000
# Medical Industry     count     3.000000
#                      mean   2006.666667
#                      std       4.618802
#                      min    2004.000000
#                      25%    2004.000000
#                      50%    2004.000000
#                      75%    2008.000000
#                      max    2012.000000
# Nonprofit            count     2.000000
#                      mean   2003.000000
#                      std       1.414214
#                      min    2002.000000
#                      25%    2002.500000
#                      50%    2003.000000
#                      75%    2003.500000
#                      max    2004.000000
# Outside Industry     count    24.000000
#                      mean   2007.875000
#                      std       3.814304
#                      min    2002.000000
#                      25%    2004.750000
#                      50%    2008.000000
#                      75%    2011.250000
#                      max    2013.000000
# Postdoc              count    23.000000
#                      mean   2010.565217
#                      std       1.829707
#                      min    2007.000000
#                      25%    2009.000000
#                      50%    2011.000000
#                      75%    2012.000000
#                      max    2013.000000
# Scientific Research  count     9.000000
#                      mean   2006.222222
#                      std       2.862594
#                      min    2002.000000
#                      25%    2005.000000
#                      50%    2006.000000
#                      75%    2008.000000
#                      max    2011.000000

# %%
NUM_COLORS=7
cm = plt.get_cmap('Paired')
df2=df.groupby(['Career Type'])
bins=np.arange(13)+2002.-0.5
#n=np.arange(13)+2002.
#x_label=['%i' % i for i in n]
y=[group['Year'] for name, group in df2]
names=[str(name) for name, group in df2]

fig,ax=plt.subplots(figsize=(15,7))
ax.set_color_cycle([cm(1.*i/NUM_COLORS) for i in range(NUM_COLORS)])
plot=ax.hist(y, bins=bins, stacked=True, normed = True, label=names)
box=ax.get_position()
ax.set_position([box.x0, box.y0, box.width * 0.8, box.height])
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
#ax.set_xticklabels(x_label)

# %%
NUM_COLORS = 28

cm = plt.get_cmap('Paired')
df2=df.groupby(['Supervisor1'])
bins=np.arange(13)+2002.-0.5
#n=np.arange(13)+2002.
#x_label=['%i' % i for i in n]
y=[group['Year'] for name, group in df2]
names=[str(name) for name, group in df2]

fig,ax=plt.subplots(figsize=(15,7))
ax.set_color_cycle([cm(1.*i/NUM_COLORS) for i in range(NUM_COLORS)])
ax.hist(y, bins=bins, alpha=1.0, stacked=True, normed = True, label=names)
box=ax.get_position()
ax.set_position([box.x0, box.y0, box.width * 0.8, box.height])
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
#ax.set_xticklabels(x_label)

# %%
NUM_COLORS = 7

cm = plt.get_cmap('Paired')
df2=df.groupby(['Area'])
bins=np.arange(13)+2002.-0.5
#n=np.arange(13)+2002.
#x_label=['%i' % i for i in n]
y=[group['Year'] for name, group in df2]
names=[str(name) for name, group in df2]

fig,ax=plt.subplots(figsize=(15,7))
ax.set_color_cycle([cm(1.*i/NUM_COLORS) for i in range(NUM_COLORS)])
ax.hist(y, bins=bins, alpha=1.0, stacked=True, normed = True, label=names)
box=ax.get_position()
ax.set_position([box.x0, box.y0, box.width * 0.8, box.height])
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
#ax.set_xticklabels(x_label)

# %%
# ?plt.get_cmap

# %%
df3=df2=df.groupby(['Career Type','Year'])
x=[group['Title'] for name, group in df3]

[', '.join(group['Title'].values) for name, group in df3 if name[0]=='Academic']

# %%
a=['a','b','c']

# %%
','.join(a)
# Out:
# 'a,b,c'
